# %%
# %load_ext autoreload
# %autoreload 2

# %%
from compactreasoningmodels.experiments.heatmap_store import HeatmapStore
from compactreasoningmodels.datasets.nonogram_dataset import NonogramDataset
from torch.utils.data import DataLoader
import os
os.chdir("../")

# %%
dataset = NonogramDataset(
    data="data/raw/nonogram_5x5_tiny.jsonl",
)
dataloader = DataLoader(dataset, batch_size=2, shuffle=True)

# %%
heatmap_store = HeatmapStore(dataloader)

# %%
experiments = [
    ("arc_consistency", 1),
    ("arc_consistency", 2),
    ("local_min_violations", 10),
    ("global_min_violations", 10),
    ("discrete_genetic", 10),
    ("discrete_genetic", 30),
    ("model_solver", 1),
    ("model_solver", 9),
]
heatmap_store.add_heatmaps(experiments)
print("Heatmaps generated and stored.")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 11
#       7     ("discrete_genetic", 30),
#       8     ("model_solver", 1),
#       9     ("model_solver", 9),
#      10 ]
# ---> 11 heatmap_store.add_heatmaps(experiments)
#      12 print("Heatmaps generated and stored.")
#
# File ~/PhD/CompactReasoningModels/src/compactreasoningmodels/experiments/heatmap_store.py:54, in HeatmapStore.add_heatmaps(self, solver_profiles)
#      52 for input_tensor, target_grid, _, _ in self.dataloader:
#      53     solver_class = self._solvers[solver_profile.name]
# ---> 54     solver_instance = solver_class(
#      55         input_tensor, target_shape,
#      56         initial_grid=self.initial_grid)
#      57     heatmap = solver_instance.heatmap(num_steps=solver_profile.num_steps)
#      58     results.append((heatmap, input_tensor, target_grid.squeeze(0).numpy()))
#
# File ~/PhD/CompactReasoningModels/src/compactreasoningmodels/solving_traces/base.py:13, in SolvingTrace.__init__(self, clues, grid_shape, initial_grid)
#       9 def __init__(self, clues: np.ndarray | torch.Tensor,
#      10              grid_shape: tuple[int, int],
#      11              initial_grid: np.ndarray | torch.Tensor | None = None):
#      12     super().__init__()
# ---> 13     self.clues = self._normalize_clues(clues, grid_shape)
#      14     self.grid_size = grid_shape
#      15     self.initial_grid = (
#      16         self._as_numpy(initial_grid) if initial_grid is not None
#      17         else self._blank_grid(*grid_shape)
#      18     )
#
# File ~/PhD/CompactReasoningModels/src/compactreasoningmodels/solving_traces/base.py:62, in SolvingTrace._normalize_clues(clues, grid_shape)
#      59 if arr.ndim == 3 and arr.shape[0] == 2:
#      60     return arr
# ---> 62 raise ValueError(
#      63     f"clues must be a tensor/array of shape ({flat_len},) or "
#      64     f"(1, {flat_len}) with the flat [row clues; column clues] dataloader "
#      65     f"layout, or a stacked array of shape (2, H, K). Got shape {arr.shape}"
#      66 )
#
# ValueError: clues must be a tensor/array of shape (30,) or (1, 30) with the flat [row clues; column clues] dataloader layout, or a stacked array of shape (2, H, K). Got shape (2, 30)

# %%
heatmap_store.ascii_distribution()
# Out:
# arc_consistency (steps=1)
# ----------------------------------------------------------------------
#   Count: 125 values
#   Mean: 0.5215
#   Std: 0.3985
#   Min: 0.0000
#   Max: 1.0000
#
# 0.00-0.05: ███████████ 8.8%
# 0.05-0.10: ██████ 4.8%
# 0.10-0.15: ███████████████████ 14.4%
# 0.15-0.20: █████ 4.0%
# 0.20-0.25: ███████ 5.6%
# 0.25-0.30: █ 0.8%
# 0.30-0.35: ███████████████ 12.0%
# 0.35-0.40: ██ 1.6%
# 0.40-0.45:
# 0.45-0.50:
# 0.50-0.55: █████████ 7.2%
# 0.55-0.60:
# 0.60-0.65:
# 0.65-0.70: ████ 3.2%
# 0.70-0.75:
# 0.75-0.80:
# 0.80-0.85:
# 0.85-0.90:
# 0.90-0.95:
# 0.95-1.00: ██████████████████████████████████████████████████ 37.6%
# ----------------------------------------------------------------------
#
# arc_consistency (steps=2)
# ----------------------------------------------------------------------
#   Count: 125 values
#   Mean: 0.4720
#   Std: 0.4691
#   Min: 0.0000
#   Max: 1.0000
#
# 0.00-0.05: ██████████████████████████████████████████████████ 44.0%
# 0.05-0.10:
# 0.10-0.15:  0.8%
# 0.15-0.20:
# 0.20-0.25: ███ 3.2%
# 0.25-0.30: ██ 2.4%
# 0.30-0.35:  0.8%
# 0.35-0.40:
# 0.40-0.45:
# 0.45-0.50:
# 0.50-0.55: ██████ 5.6%
# 0.55-0.60:
# 0.60-0.65:
# 0.65-0.70:
# 0.70-0.75:
# 0.75-0.80: █ 1.6%
# 0.80-0.85:
# 0.85-0.90:
# 0.90-0.95:
# 0.95-1.00: ███████████████████████████████████████████████ 41.6%
# ----------------------------------------------------------------------
#
# local_min_violations (steps=10)
# ----------------------------------------------------------------------
#   Count: 125 values
#   Mean: 0.5352
#   Std: 0.3949
#   Min: 0.0003
#   Max: 0.9997
#
# 0.00-0.05: ███████████████████████████████████████████ 22.4%
# 0.05-0.10: ████ 2.4%
# 0.10-0.15: ███████ 4.0%
# 0.15-0.20: ███████ 4.0%
# 0.20-0.25: ██████ 3.2%
# 0.25-0.30: ████ 2.4%
# 0.30-0.35: ███ 1.6%
# 0.35-0.40:
# 0.40-0.45: ███ 1.6%
# 0.45-0.50:
# 0.50-0.55: ███████ 4.0%
# 0.55-0.60: ███ 1.6%
# 0.60-0.65: ████████████ 6.4%
# 0.65-0.70: █ 0.8%
# 0.70-0.75: ███████ 4.0%
# 0.75-0.80: ██████████ 5.6%
# 0.80-0.85: █████████ 4.8%
# 0.85-0.90: ███ 1.6%
# 0.90-0.95: ███████ 4.0%
# 0.95-1.00: ██████████████████████████████████████████████████ 25.6%
# ----------------------------------------------------------------------
#
# global_min_violations (steps=10)
# ----------------------------------------------------------------------
#   Count: 125 values
#   Mean: 0.5225
#   Std: 0.3964
#   Min: 0.0000
#   Max: 0.9985
#
# 0.00-0.05: ██████████████████████████████████████████████ 21.6%
# 0.05-0.10: █████████████ 6.4%
# 0.10-0.15: ████████ 4.0%
# 0.15-0.20: █████ 2.4%
# 0.20-0.25: █ 0.8%
# 0.25-0.30: ███ 1.6%
# 0.30-0.35: ██████ 3.2%
# 0.35-0.40: ██████████ 4.8%
# 0.40-0.45:
# 0.45-0.50:
# 0.50-0.55: ██████ 3.2%
# 0.55-0.60: ████████ 4.0%
# 0.60-0.65: █████ 2.4%
# 0.65-0.70: ███ 1.6%
# 0.70-0.75: █████ 2.4%
# 0.75-0.80: █████ 2.4%
# 0.80-0.85: █████████████ 6.4%
# 0.85-0.90: ██████ 3.2%
# 0.90-0.95: █████████████ 6.4%
# 0.95-1.00: ██████████████████████████████████████████████████ 23.2%
# ----------------------------------------------------------------------
#
# discrete_genetic (steps=10)
# ----------------------------------------------------------------------
#   Count: 125 values
#   Mean: 0.4867
#   Std: 0.3624
#   Min: 0.0000
#   Max: 1.0000
#
# 0.00-0.05: ████████████████████████████████████ 10.4%
# 0.05-0.10: ██████████████████████████████████████████████████ 14.4%
# 0.10-0.15: ███████████████████ 5.6%
# 0.15-0.20: ████████ 2.4%
# 0.20-0.25: ███████████████████ 5.6%
# 0.25-0.30: ███████████████████ 5.6%
# 0.30-0.35: ███████████ 3.2%
# 0.35-0.40: ██ 0.8%
# 0.40-0.45: ██ 0.8%
# 0.45-0.50:
# 0.50-0.55: █████ 1.6%
# 0.55-0.60: ███████████ 3.2%
# 0.60-0.65: ███████████ 3.2%
# 0.65-0.70: █████████████ 4.0%
# 0.70-0.75: ██████████████████████ 6.4%
# 0.75-0.80: ████████████████ 4.8%
# 0.80-0.85: █████████████ 4.0%
# 0.85-0.90: ███████████ 3.2%
# 0.90-0.95: █████████████████████████ 7.2%
# 0.95-1.00: ███████████████████████████████████████████████ 13.6%
# ----------------------------------------------------------------------
#
# discrete_genetic (steps=30)
# ----------------------------------------------------------------------
#   Count: 125 values
#   Mean: 0.4898
#   Std: 0.4037
#   Min: 0.0000
#   Max: 1.0000
#
# 0.00-0.05: ██████████████████████████████████████████████████ 22.4%
# 0.05-0.10: █████████████████ 8.0%
# 0.10-0.15: ███████ 3.2%
# 0.15-0.20: ███████████████████ 8.8%
# 0.20-0.25: █████ 2.4%
# 0.25-0.30:
# 0.30-0.35: █████ 2.4%
# 0.35-0.40: █ 0.8%
# 0.40-0.45: █ 0.8%
# 0.45-0.50: █ 0.8%
# 0.50-0.55: █ 0.8%
# 0.55-0.60: █████ 2.4%
# 0.60-0.65: █ 0.8%
# 0.65-0.70: ████████ 4.0%
# 0.70-0.75:
# 0.75-0.80: ████████ 4.0%
# 0.80-0.85: ██████████████ 6.4%
# 0.85-0.90: ████████ 4.0%
# 0.90-0.95: ███████████████████████ 10.4%
# 0.95-1.00: ███████████████████████████████████████ 17.6%
# ----------------------------------------------------------------------
#
# model_solver (steps=1)
# ----------------------------------------------------------------------
#   Count: 125 values
#   Mean: 0.6291
#   Std: 0.2449
#   Min: 0.0831
#   Max: 0.9940
#
# 0.00-0.05:
# 0.05-0.10: ██████ 1.6%
# 0.10-0.15:
# 0.15-0.20: █████████████████████ 5.6%
# 0.20-0.25: ████████████ 3.2%
# 0.25-0.30: ████████████ 3.2%
# 0.30-0.35:
# 0.35-0.40: █████████████████████ 5.6%
# 0.40-0.45: ██████████████████ 4.8%
# 0.45-0.50: ██████████████████ 4.8%
# 0.50-0.55: █████████████████████████████████████ 9.6%
# 0.55-0.60: ████████████████████████████ 7.2%
# 0.60-0.65: █████████████████████████ 6.4%
# 0.65-0.70: ██████████████████ 4.8%
# 0.70-0.75: ██████████████████ 4.8%
# 0.75-0.80: █████████████████████ 5.6%
# 0.80-0.85: ████████████████████████████ 7.2%
# 0.85-0.90: ████████████████████████████ 7.2%
# 0.90-0.95: ██████████████████████████████████████████████████ 12.8%
# 0.95-1.00: █████████████████████ 5.6%
# ----------------------------------------------------------------------
#
# model_solver (steps=9)
# ----------------------------------------------------------------------
#   Count: 125 values
#   Mean: 0.4653
#   Std: 0.4425
#   Min: 0.0000
#   Max: 1.0000
#
# 0.00-0.05: ██████████████████████████████████████████████████ 36.0%
# 0.05-0.10: ████████ 6.4%
# 0.10-0.15: ████ 3.2%
# 0.15-0.20: ███ 2.4%
# 0.20-0.25: ██ 1.6%
# 0.25-0.30:
# 0.30-0.35: █ 0.8%
# 0.35-0.40: █ 0.8%
# 0.40-0.45: ███ 2.4%
# 0.45-0.50: ██ 1.6%
# 0.50-0.55: █ 0.8%
# 0.55-0.60:
# 0.60-0.65:
# 0.65-0.70: ██ 1.6%
# 0.70-0.75:
# 0.75-0.80: █ 0.8%
# 0.80-0.85: ████ 3.2%
# 0.85-0.90: ███ 2.4%
# 0.90-0.95: ███████ 5.6%
# 0.95-1.00: ██████████████████████████████████████████ 30.4%
# ----------------------------------------------------------------------

# %%
heatmap_store.display_accuracy()
# Out:
# arc_consistency (steps=1): Accuracy = 0.00%
# arc_consistency (steps=2): Accuracy = 0.00%
# local_min_violations (steps=10): Accuracy = 0.00%
# global_min_violations (steps=10): Accuracy = 0.00%
# discrete_genetic (steps=10): Accuracy = 0.00%
# discrete_genetic (steps=30): Accuracy = 0.00%
# model_solver (steps=1): Accuracy = 0.00%
# model_solver (steps=9): Accuracy = 0.00%

# %%
heatmap_store.display_mse_loss()
# Out:
# arc_consistency (steps=1): Average Loss = 0.0169
# arc_consistency (steps=2): Average Loss = 0.0078
# local_min_violations (steps=10): Average Loss = 0.0495
# global_min_violations (steps=10): Average Loss = 0.0599
# discrete_genetic (steps=10): Average Loss = 0.0097
# discrete_genetic (steps=30): Average Loss = 0.0064
# model_solver (steps=1): Average Loss = 0.0305
# model_solver (steps=9): Average Loss = 0.0084

# %%
heatmap_store.display_clue_loss()
# Out:
# arc_consistency (steps=1): Average Loss = 0.2015
# arc_consistency (steps=2): Average Loss = 0.1929
# local_min_violations (steps=10): Average Loss = 0.1996
# global_min_violations (steps=10): Average Loss = 0.2044
# discrete_genetic (steps=10): Average Loss = 0.2052
# discrete_genetic (steps=30): Average Loss = 0.2001
# model_solver (steps=1): Average Loss = 0.2303
# model_solver (steps=9): Average Loss = 0.1945

# %%
from compactreasoningmodels.experiments.noisy_similarity import NoisySimilarityExperiment
from compactreasoningmodels.solving_traces.similarity_measures import MSE, MAE, HuberLoss, MeanCosineSimilarity, PearsonCorrelation, SSIMSimilarity, WassersteinSimilarity

# %%
metrics = [
    MSE(),
    # MAE(),
    # HuberLoss(),
    MeanCosineSimilarity(),
    PearsonCorrelation(),
    # SSIMSimilarity(),
    # WassersteinSimilarity()
]
noisy_experiment = NoisySimilarityExperiment()
